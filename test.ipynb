# %%
class Registration:
    def __init__(self, student_names, student_ids, course_details, course_count,course_students):
        self.student_names = student_names
        self.student_ids = student_ids
        self.course_details = course_details
        self.course_count = course_count
        self.course_students=course_students

    def validation(self, student_name, student_id):
        if student_name in self.student_names and self.student_ids.get(student_name) == student_id:
            print()
            print("Login Successful")
            return False
        
        elif student_name in self.student_names and student_id not in self.student_ids.values():
            print()
            print("Invalid user credentials. Login failed.")
            return True
        
        elif student_id in self.student_ids.values() and student_name not in self.student_names:
            print()
            print("Invalid user credentials. Login failed.")
            return True
        
        else:
            print()
            print("Invalid user credentials. Login failed.")
            print()
            choice=input('Login or Signup (login/signup):').lower()
            if choice=='signup':
                print()
                print("Successfully Signed up")
                return False
                
            else:
                return True
            
        

    def new_validation(self, student_name, student_id):
        if student_name not in self.student_names and student_id not in self.student_ids.values():
            print()
            print('Registered Successfully')
            return True
               

        elif student_name in self.student_names and student_id not in self.student_ids.values():
            print()
            print('User name already taken')
            return False

        elif student_id in self.student_ids.values() and student_name not in self.student_names:
            print()
            print('Id already in use')
            return False
        else:
            print()
            print('User Already Exists')
            print()
            choice=input('Login or Signup (login/signup):').lower()
            if choice=='login':
                print()
                print("Successfully Logged in")
                return True
            else:
                return False

    def course(self, chosen_course, student_name):
        if chosen_course in self.course_details:
            print(f"Successfully registered for the course {chosen_course}")
            return True
        else:
            print("Invalid course selection. Try again.")
            return False

    def course_count1(self,student_name):
        available_courses = []
        for key, value in self.course_count.items():
            if value < 2 and student_name not in self.course_students[key]:
                available_courses.append(key)
        if available_courses:
            return True,available_courses
        else:
            return False,[]

    def notification(self, student_name, chosen_course='', success=True):
        if success:
            print(f"Dear {student_name}, You have successfully registered for the course {chosen_course}")
        else:
            print(f"Dear {student_name}, Registration for the course was not successful. Please try again.")

    def signup(self):
        b = input('Login or Signup (login/signup):').lower()
        if b == 'login':
            self.register()

        elif b == 'signup':
            self.new_user()
        else:
            print('Invalid Option')

    def register(self):
        new_student=[]
        student_name = input('Enter your name: ').lower()
        student_id = int(input('Enter your id: '))
        while self.validation(student_name, student_id):
            if student_name in self.student_names and student_id not in self.student_ids.values():
                student_id = int(input("Enter correct Id:"))
            elif student_id in self.student_ids.values() and student_name not in self.student_names:
                student_name = input('Enter your correct name:')
            else:
                student_name = input("Enter your name:")
                student_id = int(input('Enter your id: '))
        print(student_name, student_id)
        if student_name not in student_names and student_id not in self.student_ids:
            self.student_names.append(student_name)
            self.student_ids[student_name] = student_id
                
        print(self.student_ids)
        print(self.student_names)
        available, available_courses = self.course_count1(student_name)  # Call course_count1 method
        if available:
            print()
            print('Available Courses:')
            for course in available_courses:
                print(course)
            print()
            chosen_course = input("Enter the course name: ").lower()
            while not self.course(chosen_course, student_name):
                chosen_course = input("Enter the course name: ").lower()
            print()
            self.notification(student_name, chosen_course)
            self.course_count[chosen_course] += 1
            print(self.course_count)
            print()
            new_student.append(student_name)
            self.course_students[chosen_course].extend(new_student)
            print(self.course_students)
        else:
            print('No courses available at the moment')

    def new_user(self):
        new_student=[]
        print()
        print('Signup')
        student_name = input('Enter your name: ').lower()
        student_id = int(input('Enter your id: '))
        while not self.new_validation(student_name, student_id):
            if student_name in self.student_names and student_id not in self.student_ids.values():
                student_name = input("Enter another name:")
            elif student_id in self.student_ids.values() and student_name not in self.student_names:
                student_id = int(input('Enter your id: '))
            else:
                student_name = input("Enter your name:")
                student_id = int(input('Enter your id: '))
        
        print()
        print(student_name, student_id)
        self.student_names.append(student_name)
        self.student_ids[student_name] = student_id
        print(self.student_ids)
        print(self.student_names)
        print()
        available, available_courses = self.course_count1(student_name)
        if available:
            print('Available Courses:')
            for course in available_courses:
                print(course)
            print()
            chosen_course = input("Enter the course name: ").lower()
            while not self.course(chosen_course, student_name):
                chosen_course = input("Enter the course name: ").lower()
            print()
            self.notification(student_name, chosen_course)
            self.course_count[chosen_course] += 1
            print(self.course_count)
            print()
            new_student.append(student_name)
            self.course_students[chosen_course].extend(new_student)
            print(self.course_students)
            
            
            
        else:
            print('No courses available at the moment')


# Test
course_details = [
    "python",
    "sql",
    "java",
    "hadoop"]

course_count = {'python': 0, 'sql': 0, 'java': 0, 'hadoop': 0}

course_students={'python': [], 'sql': [], 'java': [], 'hadoop': []}





student_names = ['venkat', 'ajay', 'sujan', 'tanishq']
student_ids = {'venkat': 101, 'ajay': 102, 'sujan': 103, 'tanishq': 104}

registration = Registration(student_names, student_ids, course_details, course_count,course_students)




people = 0
while people < 5:
    registration.signup()
    people += 1
    

print(details)
